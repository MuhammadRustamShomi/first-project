# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadRustamShomi/first-project/blob/master/web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = 'https://www.whatmobile.com.pk/'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
content = response.content

# %%
len(content)
# Out:
# 59009

# %%
soup = BeautifulSoup(content,"html.parser")

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <base href="" target="_self"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="BBCXWny4cq7hMjuYiwgOApODrXMcsyjapahWC_RiEjI" name="google-site-verification"/>
# <title>Mobile phone prices - Pakistan's daily updated mobile phone prices Pakistan What Mobile</title>
# <meta content="1f4b6fa75ca4c410" name="y_key"/>
# <meta content="Mobile Prices in Pakistan 2018, Daily Updated Mobile Prices, What Mobile Pakistan, Prices Lg mobile, Nokia Mobile Prices Pakistan HTC Mobile Rates, Huawei Mobile Prices, Samsung Mobile prices, Sony Ericsson Mobile" name="Description"/>
# <meta content="Mobile Prices, Lg Mobile Prices , mobile phone Prices, What, mobile, what mobile, pakistan, mobile phone, Mobile Phone Pakistan, phone, nokia, samsung, sony ericsson, prices, motorola, HTC, zone,  Mobile Zone," name="Keywords"/>
# <meta content="PK" name="sitecode">
# ...

# %%
links = soup.find_all('li',{'class': 'product'})

# %%
pic = []
for link in links:
  pic.append(url+link.find('img')['src'])

# %%
pic
# Out:
# ['https://www.whatmobile.com.pk/admin/images/Xiaomi/XiaomiMi11-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/Vivo/VivoV21-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/Oppo/OppoF19-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/Samsung/SamsungGalaxyA32-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/Xiaomi/XiaomiRedmiNote10S-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/Infinix/InfinixNote10Pro-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/OnePlus/OnePlusNord12GB-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/OnePlus/OnePlusNord-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/OnePlus/OnePlus8T12GB-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/OnePlus/OnePlus812GB-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/Xiaomi/XiaomiPocoF38GB-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/OnePlus/OnePlus8Pro12GB-s.jpg',
#  'https://www.whatmobile.com.pk/admin/images/Xiaomi/XiaomiPocoX3Pro8GB-s.jpg',
# ...

# %%
pics = links.find("img")

# %%
url+pic['src']
# Out:
# 'https://www.whatmobile.com.pk/admin/images/Xiaomi/XiaomiMi11-s.jpg'

# %%
soup.title.string
# Out:
# "Mobile phone prices - Pakistan's daily updated mobile phone prices Pakistan What Mobile"

# %%
soup.body
# Out:
# <body>
# <div style="width:1000px;margin: auto;">
# <div style="width: 100%">
# <link href="css/search.css" rel="stylesheet" type="text/css">
# <style>
# #container {
# margin-top: 10px !important;
# }
# </style>
# <div style="width:1000px;">
# <div itemscope="" itemtype="http://schema.org/Organization">
# <meta content="What Mobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# <meta content="https://m.whatmobile.com.pk/" itemprop="sameAs"/>
# <meta content="https://www.facebook.com/whatmobile.com.pk/" itemprop="sameAs"/>
# </div>
# <div itemscope="" itemtype="http://schema.org/WebSite">
# <meta content="WhatMobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# </div>
# <div style="width:998px">
# <div style="width:764px; float:left">
# <img alt="Mobile Prices" border="0" height="137" src="images/header-Left-new2.gif" usemap="#Map" width="764"/>
# <map id="Map" name="Map">
# ...

# %%
soup.body.div.a
# Out:
# <a href="#" id="go">Go</a>

# %%
table = soup.find_all('td')

# %%
len(table)
# Out:
# 23

# %%
url+table[0].text
# Out:
# "https://www.whatmobile.com.pk/\n\n\ngoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1377952911391-0'); });\n\n\n\n\n\ngoogletag.cmd.push(function() { googletag.display('div-gpt-ad-1387525175047-0'); });\n\n\n\xa0\n"

# %%
pics = links.find_all('img')

# %%
len(pics)
# Out:
# 1

# %%
pc = []
for pc in pics:
  pr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4753ff2402b4> in <module>()
#       1 pc = []
#       2 for pc in pics:
# ----> 3   pr
#
# NameError: name 'pr' is not defined
